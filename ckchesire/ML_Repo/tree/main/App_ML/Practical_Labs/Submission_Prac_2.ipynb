# %% [markdown]
# <a href="https://colab.research.google.com/github/ckchesire/ML_Repo/blob/main/ckchesire/ML_Repo/tree/main/App_ML/Practical_Labs/Submission_Prac_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Get and understand the data

# %% [markdown]
# #Prepare Data for Modelling

# %% [markdown]
# # Implement machine learning models

# %% [markdown]
# # Evaluate Models
